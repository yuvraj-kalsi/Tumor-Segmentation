# %%
import pandas as pd
import numpy as np
import matplotlib as mtp
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow import keras
import tensorflow as tf
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
from glob import glob

msk_paths = glob('../input/lgg-mri-segmentation/kaggle_3m/*/*_mask*')
img_paths = [m.replace('_mask','') for m in msk_paths]

# %%
import cv2

rows, cols = 10, 2

fig = plt.figure(figsize = (4, 20))
for i in range(1, rows*cols, 2):
    
    fig.add_subplot(rows, cols, i)
    img = cv2.imread(img_paths[i])
    plt.imshow(img)

    fig.add_subplot(rows, cols, i+1)
    msk = cv2.imread(msk_paths[i])
    plt.imshow(msk)

# %%
mri_df = pd.DataFrame({'img':img_paths,
                       'msk':msk_paths})
mri_df.head()
# Out:
#                                                  img  \
# 0  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 1  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 2  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 3  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 4  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
#
#                                                  msk
# 0  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 1  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 2  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 3  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 4  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...

# %%
from sklearn.model_selection import train_test_split

mri_df_train, mri_df_test = train_test_split(mri_df, test_size = 0.1,random_state=77_47)
mri_df_train, mri_df_val = train_test_split(mri_df_train, test_size = 0.1,random_state=77_47)

mri_df_train = mri_df_train.reset_index(drop=True)
mri_df_val = mri_df_val.reset_index(drop=True)
mri_df_test = mri_df_test.reset_index(drop=True)

# %%
print(mri_df_train.shape,
      mri_df_val.shape,
      mri_df_test.shape)
# Out:
# (3182, 2) (354, 2) (393, 2)

# %%
from keras.preprocessing.image import ImageDataGenerator

# assuming an human precision of 1% for manual tasks, so I'll use 2% for a safaty error margin
BATCH_SIZE = 32

def transformator(df,
                  rotation_range=0.2,
                  width_shift_range=0.02,
                  height_shift_range=0.02,
                  shear_range=0.1,
                  zoom_range=0.1,
                  horizontal_flip=True,
                  IMG_SIZE_TRAIN = (128,128),
                  BATCH_SIZE = 32):

  img_datag = ImageDataGenerator(
                rotation_range=rotation_range,
                width_shift_range=width_shift_range,
                height_shift_range=height_shift_range,
                shear_range=shear_range,
                zoom_range=zoom_range,
                horizontal_flip=True,
                fill_mode='nearest')

  msk_datag = ImageDataGenerator(
                rotation_range=rotation_range,
                width_shift_range=width_shift_range,
                height_shift_range=height_shift_range,
                shear_range=shear_range,
                zoom_range=zoom_range,
                horizontal_flip=True,
                fill_mode='nearest')

  img_generated = img_datag.flow_from_dataframe(
                      df,
                      x_col = 'img',
                      class_mode = None,
                      color_mode = 'rgb',
                      target_size = IMG_SIZE_TRAIN,
                      batch_size = BATCH_SIZE,
                      save_to_dir = None,
                      save_prefix = 'image',
                      seed = 777447)

  msk_generated = msk_datag.flow_from_dataframe(
                      df,
                      x_col='msk',
                      class_mode=None,
                      color_mode='grayscale',
                      target_size=IMG_SIZE_TRAIN,
                      batch_size=BATCH_SIZE,
                      save_to_dir=None,
                      save_prefix='mask',
                      seed=777447)

  generated = zip(img_generated, msk_generated)

  for img, msk in generated:
      img = img / 255
      msk = msk / 255

      msk[msk > 0.5] = 1
      msk[msk <= 0.5] = 0

      yield (img,msk)

data_train = transformator(mri_df_train)
data_val = transformator(mri_df_val)
data_test = transformator(mri_df_test)

# %%
import keras.layers as ls
import keras

inp = ls.Input((128,128,3))

c1 = ls.Conv2D(32, (3, 3),padding='same')(inp)
b1 = ls.Activation('relu')(c1)
c1 = ls.Conv2D(32, (3, 3), padding='same')(b1)
b1 = ls.BatchNormalization(axis=3)(c1)
b1 = ls.Activation('relu')(b1)
p1 = ls.MaxPooling2D(pool_size=(2, 2))(b1)

c2 = ls.Conv2D(64, (3,3),padding='same')(p1)
b2 = ls.Activation('relu')(c2)
c2 = ls.Conv2D(64, (3, 3), padding='same')(b2)
b2 = ls.BatchNormalization(axis=3)(c2)
b2 = ls.Activation('relu')(b2)
p2 = ls.MaxPooling2D(pool_size=(2, 2))(b2)

c3 = ls.Conv2D(128, (3,3),padding='same')(p2)
b3 = ls.Activation('relu')(c3)
c3 = ls.Conv2D(128, (3, 3), padding='same')(b3)
b3 = ls.BatchNormalization(axis=3)(c3)
b3 = ls.Activation('relu')(b3)
p3 = ls.MaxPooling2D(pool_size=(2, 2))(b3)

c4 = ls.Conv2D(256, (3,3),padding='same')(p3)
b4 = ls.Activation('relu')(c4)
c4 = ls.Conv2D(256, (3, 3), padding='same')(b4)
b4 = ls.BatchNormalization(axis=3)(c4)
b4 = ls.Activation('relu')(b4)
p4 = ls.MaxPooling2D(pool_size=(2, 2))(b4)

c5 = ls.Conv2D(512, (3,3),padding='same')(p4)
b5 = ls.Activation('relu')(c5)
c5 = ls.Conv2D(512, (3, 3), padding='same')(b5)
b5 = ls.BatchNormalization(axis=3)(c5)
b5 = ls.Activation('relu')(b5)
p5 = ls.MaxPooling2D(pool_size=(2, 2))(b5)

u6 = ls.concatenate([ls.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(b5), c4], axis=3)
c6 = ls.Conv2D(256, (3, 3), padding='same')(u6)
b6 = ls.Activation('relu')(c6)
c6 = ls.Conv2D(256, (3, 3), padding='same')(b6)
b6 = ls.BatchNormalization(axis=3)(c6)
b6 = ls.Activation('relu')(b6)

u7 = ls.concatenate([ls.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(b6), c3], axis=3)
c7 = ls.Conv2D(128, (3, 3), padding='same')(u7)
b7 = ls.Activation('relu')(c7)
c7 = ls.Conv2D(128, (3, 3), padding='same')(b7)
b7 = ls.BatchNormalization(axis=3)(c7)
b7 = ls.Activation('relu')(b7)

u8 = ls.concatenate([ls.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(b7), c2], axis=3)
c8 = ls.Conv2D(64, (3, 3), padding='same')(u8)
b8 = ls.Activation('relu')(c8)
c8 = ls.Conv2D(64, (3, 3), padding='same')(b8)
b8 = ls.BatchNormalization(axis=3)(c8)
b8 = ls.Activation('relu')(b8)

u9 = ls.concatenate([ls.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(b8), c1], axis=3)
c9 = ls.Conv2D(32, (3, 3), padding='same')(u9)
b9 = ls.Activation('relu')(c9)
c9 = ls.Conv2D(32, (3, 3), padding='same')(b9)
b9 = ls.BatchNormalization(axis=3)(c9)
b9 = ls.Activation('relu')(b9)

c10 = ls.Conv2D(1, (1, 1), activation='sigmoid')(b9)

model = keras.Model(inputs=[inp],
                    outputs=[c10])

# %%
keras.utils.plot_model(model,show_shapes=True)

# %%
import keras.backend as K

smooth=100

def dice_coef(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)

    intersec = K.sum(y_true * y_pred)
    mod_sum = K.sum(y_true) + K.sum(y_pred)

    return (2 * intersec + smooth) / (mod_sum + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersec = K.sum(y_true * y_pred)
    comb_area = K.sum(y_true + y_pred) - intersec

    return (intersec + smooth) / (comb_area + smooth)

def iou_loss(y_true, y_pred):
  return - iou(y_true, y_pred)

# %%
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam

model.compile(optimizer = Adam(learning_rate=0.0001),
              loss = iou_loss,
              metrics=["binary_accuracy", iou, dice_coef])


history = model.fit(data_train,
                    steps_per_epoch=(len(mri_df_train) / BATCH_SIZE),
                    epochs=60,
                    callbacks=[ModelCheckpoint('unet_128_mri_seg.hdf5', verbose=1, save_best_only=True)],
                    validation_data = data_val,
                    validation_steps=len(mri_df_val) / BATCH_SIZE)
# Out:
# Found 3182 validated image filenames.
# Found 3182 validated image filenames.
# Epoch 1/60
# 100/99 [==============================] - ETA: 0s - loss: -0.0492 - binary_accuracy: 0.9218 - iou: 0.0493 - dice_coef: 0.0921Found 354 validated image filenames.
# Found 354 validated image filenames.
#
# Epoch 1: val_loss improved from inf to -0.01291, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 86s 738ms/step - loss: -0.0492 - binary_accuracy: 0.9218 - iou: 0.0493 - dice_coef: 0.0921 - val_loss: -0.0129 - val_binary_accuracy: 0.9900 - val_iou: 0.0127 - val_dice_coef: 0.0237
# Epoch 2/60
# 100/99 [==============================] - ETA: 0s - loss: -0.0766 - binary_accuracy: 0.9802 - iou: 0.0764 - dice_coef: 0.1397
# Epoch 2: val_loss improved from -0.01291 to -0.02162, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 37s 379ms/step - loss: -0.0766 - binary_accuracy: 0.9802 - iou: 0.0764 - dice_coef: 0.1397 - val_loss: -0.0216 - val_binary_accuracy: 0.9902 - val_iou: 0.0243 - val_dice_coef: 0.0447
# Epoch 3/60
# 100/99 [==============================] - ETA: 0s - loss: -0.0937 - binary_accuracy: 0.9859 - iou: 0.0934 - dice_coef: 0.1680
# Epoch 3: val_loss improved from -0.02162 to -0.04279, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 49s 499ms/step - loss: -0.0937 - binary_accuracy: 0.9859 - iou: 0.0934 - dice_coef: 0.1680 - val_loss: -0.0428 - val_binary_accuracy: 0.9913 - val_iou: 0.0428 - val_dice_coef: 0.0774
# Epoch 4/60
# 100/99 [==============================] - ETA: 0s - loss: -0.1172 - binary_accuracy: 0.9903 - iou: 0.1174 - dice_coef: 0.2064
# Epoch 4: val_loss improved from -0.04279 to -0.08192, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 52s 525ms/step - loss: -0.1172 - binary_accuracy: 0.9903 - iou: 0.1174 - dice_coef: 0.2064 - val_loss: -0.0819 - val_binary_accuracy: 0.9911 - val_iou: 0.0918 - val_dice_coef: 0.1600
# Epoch 5/60
# 100/99 [==============================] - ETA: 0s - loss: -0.1422 - binary_accuracy: 0.9919 - iou: 0.1424 - dice_coef: 0.2450
# Epoch 5: val_loss did not improve from -0.08192
# 99/99 [==============================] - 44s 450ms/step - loss: -0.1422 - binary_accuracy: 0.9919 - iou: 0.1424 - dice_coef: 0.2450 - val_loss: -0.0775 - val_binary_accuracy: 0.9932 - val_iou: 0.0768 - val_dice_coef: 0.1325
# Epoch 6/60
# 100/99 [==============================] - ETA: 0s - loss: -0.1714 - binary_accuracy: 0.9931 - iou: 0.1720 - dice_coef: 0.2885
# Epoch 6: val_loss improved from -0.08192 to -0.19466, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 363ms/step - loss: -0.1714 - binary_accuracy: 0.9931 - iou: 0.1720 - dice_coef: 0.2885 - val_loss: -0.1947 - val_binary_accuracy: 0.9863 - val_iou: 0.1843 - val_dice_coef: 0.2996
# Epoch 7/60
# 100/99 [==============================] - ETA: 0s - loss: -0.2078 - binary_accuracy: 0.9939 - iou: 0.2075 - dice_coef: 0.3381
# Epoch 7: val_loss did not improve from -0.19466
# 99/99 [==============================] - 37s 373ms/step - loss: -0.2078 - binary_accuracy: 0.9939 - iou: 0.2075 - dice_coef: 0.3381 - val_loss: -0.1583 - val_binary_accuracy: 0.9935 - val_iou: 0.1761 - val_dice_coef: 0.2860
# Epoch 8/60
# 100/99 [==============================] - ETA: 0s - loss: -0.2485 - binary_accuracy: 0.9946 - iou: 0.2485 - dice_coef: 0.3903
# Epoch 8: val_loss improved from -0.19466 to -0.29587, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 363ms/step - loss: -0.2485 - binary_accuracy: 0.9946 - iou: 0.2485 - dice_coef: 0.3903 - val_loss: -0.2959 - val_binary_accuracy: 0.9933 - val_iou: 0.2963 - val_dice_coef: 0.4450
# Epoch 9/60
# 100/99 [==============================] - ETA: 0s - loss: -0.3035 - binary_accuracy: 0.9956 - iou: 0.3036 - dice_coef: 0.4579
# Epoch 9: val_loss improved from -0.29587 to -0.36317, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 38s 383ms/step - loss: -0.3035 - binary_accuracy: 0.9956 - iou: 0.3036 - dice_coef: 0.4579 - val_loss: -0.3632 - val_binary_accuracy: 0.9928 - val_iou: 0.3872 - val_dice_coef: 0.5465
# Epoch 10/60
# 100/99 [==============================] - ETA: 0s - loss: -0.3558 - binary_accuracy: 0.9957 - iou: 0.3557 - dice_coef: 0.5163
# Epoch 10: val_loss did not improve from -0.36317
# 99/99 [==============================] - 37s 379ms/step - loss: -0.3558 - binary_accuracy: 0.9957 - iou: 0.3557 - dice_coef: 0.5163 - val_loss: -0.3482 - val_binary_accuracy: 0.9943 - val_iou: 0.3461 - val_dice_coef: 0.4993
# Epoch 11/60
# 100/99 [==============================] - ETA: 0s - loss: -0.4101 - binary_accuracy: 0.9963 - iou: 0.4095 - dice_coef: 0.5723
# Epoch 11: val_loss improved from -0.36317 to -0.42489, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 38s 382ms/step - loss: -0.4101 - binary_accuracy: 0.9963 - iou: 0.4095 - dice_coef: 0.5723 - val_loss: -0.4249 - val_binary_accuracy: 0.9953 - val_iou: 0.4200 - val_dice_coef: 0.5811
# Epoch 12/60
# 100/99 [==============================] - ETA: 0s - loss: -0.4651 - binary_accuracy: 0.9965 - iou: 0.4654 - dice_coef: 0.6273
# Epoch 12: val_loss improved from -0.42489 to -0.45577, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 39s 391ms/step - loss: -0.4651 - binary_accuracy: 0.9965 - iou: 0.4654 - dice_coef: 0.6273 - val_loss: -0.4558 - val_binary_accuracy: 0.9965 - val_iou: 0.4403 - val_dice_coef: 0.5960
# Epoch 13/60
# 100/99 [==============================] - ETA: 0s - loss: -0.5019 - binary_accuracy: 0.9965 - iou: 0.5012 - dice_coef: 0.6594
# Epoch 13: val_loss improved from -0.45577 to -0.51162, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 366ms/step - loss: -0.5019 - binary_accuracy: 0.9965 - iou: 0.5012 - dice_coef: 0.6594 - val_loss: -0.5116 - val_binary_accuracy: 0.9959 - val_iou: 0.5021 - val_dice_coef: 0.6449
# Epoch 14/60
# 100/99 [==============================] - ETA: 0s - loss: -0.5545 - binary_accuracy: 0.9969 - iou: 0.5551 - dice_coef: 0.7055
# Epoch 14: val_loss did not improve from -0.51162
# 99/99 [==============================] - 36s 364ms/step - loss: -0.5545 - binary_accuracy: 0.9969 - iou: 0.5551 - dice_coef: 0.7055 - val_loss: -0.4481 - val_binary_accuracy: 0.9913 - val_iou: 0.4515 - val_dice_coef: 0.5992
# Epoch 15/60
# 100/99 [==============================] - ETA: 0s - loss: -0.5898 - binary_accuracy: 0.9970 - iou: 0.5889 - dice_coef: 0.7345
# Epoch 15: val_loss improved from -0.51162 to -0.53869, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 38s 382ms/step - loss: -0.5898 - binary_accuracy: 0.9970 - iou: 0.5889 - dice_coef: 0.7345 - val_loss: -0.5387 - val_binary_accuracy: 0.9964 - val_iou: 0.5173 - val_dice_coef: 0.6529
# Epoch 16/60
# 100/99 [==============================] - ETA: 0s - loss: -0.6238 - binary_accuracy: 0.9972 - iou: 0.6242 - dice_coef: 0.7614
# Epoch 16: val_loss improved from -0.53869 to -0.61001, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 37s 379ms/step - loss: -0.6238 - binary_accuracy: 0.9972 - iou: 0.6242 - dice_coef: 0.7614 - val_loss: -0.6100 - val_binary_accuracy: 0.9962 - val_iou: 0.6061 - val_dice_coef: 0.7262
# Epoch 17/60
# 100/99 [==============================] - ETA: 0s - loss: -0.6431 - binary_accuracy: 0.9972 - iou: 0.6436 - dice_coef: 0.7778
# Epoch 17: val_loss did not improve from -0.61001
# 99/99 [==============================] - 37s 376ms/step - loss: -0.6431 - binary_accuracy: 0.9972 - iou: 0.6436 - dice_coef: 0.7778 - val_loss: -0.5676 - val_binary_accuracy: 0.9952 - val_iou: 0.5737 - val_dice_coef: 0.7038
# Epoch 18/60
# 100/99 [==============================] - ETA: 0s - loss: -0.6706 - binary_accuracy: 0.9974 - iou: 0.6711 - dice_coef: 0.7975
# Epoch 18: val_loss did not improve from -0.61001
# 99/99 [==============================] - 37s 378ms/step - loss: -0.6706 - binary_accuracy: 0.9974 - iou: 0.6711 - dice_coef: 0.7975 - val_loss: -0.5677 - val_binary_accuracy: 0.9956 - val_iou: 0.5746 - val_dice_coef: 0.7038
# Epoch 19/60
# 100/99 [==============================] - ETA: 0s - loss: -0.6706 - binary_accuracy: 0.9971 - iou: 0.6711 - dice_coef: 0.7980
# Epoch 19: val_loss improved from -0.61001 to -0.64823, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 363ms/step - loss: -0.6706 - binary_accuracy: 0.9971 - iou: 0.6711 - dice_coef: 0.7980 - val_loss: -0.6482 - val_binary_accuracy: 0.9951 - val_iou: 0.6500 - val_dice_coef: 0.7648
# Epoch 20/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7059 - binary_accuracy: 0.9975 - iou: 0.7067 - dice_coef: 0.8236
# Epoch 20: val_loss did not improve from -0.64823
# 99/99 [==============================] - 37s 373ms/step - loss: -0.7059 - binary_accuracy: 0.9975 - iou: 0.7067 - dice_coef: 0.8236 - val_loss: -0.6468 - val_binary_accuracy: 0.9969 - val_iou: 0.6405 - val_dice_coef: 0.7664
# Epoch 21/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7157 - binary_accuracy: 0.9974 - iou: 0.7161 - dice_coef: 0.8300
# Epoch 21: val_loss did not improve from -0.64823
# 99/99 [==============================] - 37s 375ms/step - loss: -0.7157 - binary_accuracy: 0.9974 - iou: 0.7161 - dice_coef: 0.8300 - val_loss: -0.6464 - val_binary_accuracy: 0.9961 - val_iou: 0.6619 - val_dice_coef: 0.7860
# Epoch 22/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7270 - binary_accuracy: 0.9974 - iou: 0.7273 - dice_coef: 0.8382
# Epoch 22: val_loss improved from -0.64823 to -0.67698, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 38s 381ms/step - loss: -0.7270 - binary_accuracy: 0.9974 - iou: 0.7273 - dice_coef: 0.8382 - val_loss: -0.6770 - val_binary_accuracy: 0.9960 - val_iou: 0.6828 - val_dice_coef: 0.7965
# Epoch 23/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7228 - binary_accuracy: 0.9974 - iou: 0.7234 - dice_coef: 0.8342
# Epoch 23: val_loss did not improve from -0.67698
# 99/99 [==============================] - 37s 374ms/step - loss: -0.7228 - binary_accuracy: 0.9974 - iou: 0.7234 - dice_coef: 0.8342 - val_loss: -0.6704 - val_binary_accuracy: 0.9966 - val_iou: 0.6845 - val_dice_coef: 0.7989
# Epoch 24/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7496 - binary_accuracy: 0.9977 - iou: 0.7498 - dice_coef: 0.8529
# Epoch 24: val_loss improved from -0.67698 to -0.72960, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 35s 359ms/step - loss: -0.7496 - binary_accuracy: 0.9977 - iou: 0.7498 - dice_coef: 0.8529 - val_loss: -0.7296 - val_binary_accuracy: 0.9971 - val_iou: 0.7362 - val_dice_coef: 0.8276
# Epoch 25/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7492 - binary_accuracy: 0.9975 - iou: 0.7493 - dice_coef: 0.8516
# Epoch 25: val_loss did not improve from -0.72960
# 99/99 [==============================] - 38s 383ms/step - loss: -0.7492 - binary_accuracy: 0.9975 - iou: 0.7493 - dice_coef: 0.8516 - val_loss: -0.7047 - val_binary_accuracy: 0.9965 - val_iou: 0.6907 - val_dice_coef: 0.7968
# Epoch 26/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7650 - binary_accuracy: 0.9977 - iou: 0.7652 - dice_coef: 0.8627
# Epoch 26: val_loss did not improve from -0.72960
# 99/99 [==============================] - 37s 373ms/step - loss: -0.7650 - binary_accuracy: 0.9977 - iou: 0.7652 - dice_coef: 0.8627 - val_loss: -0.7257 - val_binary_accuracy: 0.9975 - val_iou: 0.7149 - val_dice_coef: 0.8254
# Epoch 27/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7674 - binary_accuracy: 0.9977 - iou: 0.7673 - dice_coef: 0.8640
# Epoch 27: val_loss did not improve from -0.72960
# 99/99 [==============================] - 36s 363ms/step - loss: -0.7674 - binary_accuracy: 0.9977 - iou: 0.7673 - dice_coef: 0.8640 - val_loss: -0.7269 - val_binary_accuracy: 0.9967 - val_iou: 0.7401 - val_dice_coef: 0.8349
# Epoch 28/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7688 - binary_accuracy: 0.9977 - iou: 0.7691 - dice_coef: 0.8665
# Epoch 28: val_loss improved from -0.72960 to -0.73529, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 37s 371ms/step - loss: -0.7688 - binary_accuracy: 0.9977 - iou: 0.7691 - dice_coef: 0.8665 - val_loss: -0.7353 - val_binary_accuracy: 0.9972 - val_iou: 0.7466 - val_dice_coef: 0.8425
# Epoch 29/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7765 - binary_accuracy: 0.9977 - iou: 0.7768 - dice_coef: 0.8712
# Epoch 29: val_loss improved from -0.73529 to -0.75040, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 38s 384ms/step - loss: -0.7765 - binary_accuracy: 0.9977 - iou: 0.7768 - dice_coef: 0.8712 - val_loss: -0.7504 - val_binary_accuracy: 0.9975 - val_iou: 0.7577 - val_dice_coef: 0.8530
# Epoch 30/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7754 - binary_accuracy: 0.9977 - iou: 0.7758 - dice_coef: 0.8704
# Epoch 30: val_loss did not improve from -0.75040
# 99/99 [==============================] - 37s 375ms/step - loss: -0.7754 - binary_accuracy: 0.9977 - iou: 0.7758 - dice_coef: 0.8704 - val_loss: -0.7370 - val_binary_accuracy: 0.9971 - val_iou: 0.7440 - val_dice_coef: 0.8473
# Epoch 31/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7862 - binary_accuracy: 0.9978 - iou: 0.7867 - dice_coef: 0.8774
# Epoch 31: val_loss did not improve from -0.75040
# 99/99 [==============================] - 38s 383ms/step - loss: -0.7862 - binary_accuracy: 0.9978 - iou: 0.7867 - dice_coef: 0.8774 - val_loss: -0.7342 - val_binary_accuracy: 0.9970 - val_iou: 0.7472 - val_dice_coef: 0.8401
# Epoch 32/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7898 - binary_accuracy: 0.9979 - iou: 0.7898 - dice_coef: 0.8789
# Epoch 32: val_loss did not improve from -0.75040
# 99/99 [==============================] - 37s 370ms/step - loss: -0.7898 - binary_accuracy: 0.9979 - iou: 0.7898 - dice_coef: 0.8789 - val_loss: -0.7102 - val_binary_accuracy: 0.9962 - val_iou: 0.7256 - val_dice_coef: 0.8193
# Epoch 33/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7817 - binary_accuracy: 0.9977 - iou: 0.7821 - dice_coef: 0.8741
# Epoch 33: val_loss did not improve from -0.75040
# 99/99 [==============================] - 39s 393ms/step - loss: -0.7817 - binary_accuracy: 0.9977 - iou: 0.7821 - dice_coef: 0.8741 - val_loss: -0.7134 - val_binary_accuracy: 0.9960 - val_iou: 0.7300 - val_dice_coef: 0.8323
# Epoch 34/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7882 - binary_accuracy: 0.9978 - iou: 0.7885 - dice_coef: 0.8786
# Epoch 34: val_loss did not improve from -0.75040
# 99/99 [==============================] - 37s 377ms/step - loss: -0.7882 - binary_accuracy: 0.9978 - iou: 0.7885 - dice_coef: 0.8786 - val_loss: -0.7220 - val_binary_accuracy: 0.9973 - val_iou: 0.7393 - val_dice_coef: 0.8346
# Epoch 35/60
# 100/99 [==============================] - ETA: 0s - loss: -0.7982 - binary_accuracy: 0.9978 - iou: 0.7983 - dice_coef: 0.8849
# Epoch 35: val_loss improved from -0.75040 to -0.75657, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 37s 379ms/step - loss: -0.7982 - binary_accuracy: 0.9978 - iou: 0.7983 - dice_coef: 0.8849 - val_loss: -0.7566 - val_binary_accuracy: 0.9974 - val_iou: 0.7672 - val_dice_coef: 0.8633
# Epoch 36/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8005 - binary_accuracy: 0.9978 - iou: 0.8007 - dice_coef: 0.8859
# Epoch 36: val_loss did not improve from -0.75657
# 99/99 [==============================] - 35s 359ms/step - loss: -0.8005 - binary_accuracy: 0.9978 - iou: 0.8007 - dice_coef: 0.8859 - val_loss: -0.7092 - val_binary_accuracy: 0.9968 - val_iou: 0.7032 - val_dice_coef: 0.8145
# Epoch 37/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8037 - binary_accuracy: 0.9978 - iou: 0.8040 - dice_coef: 0.8882
# Epoch 37: val_loss did not improve from -0.75657
# 99/99 [==============================] - 40s 410ms/step - loss: -0.8037 - binary_accuracy: 0.9978 - iou: 0.8040 - dice_coef: 0.8882 - val_loss: -0.7173 - val_binary_accuracy: 0.9965 - val_iou: 0.7349 - val_dice_coef: 0.8204
# Epoch 38/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8065 - binary_accuracy: 0.9979 - iou: 0.8068 - dice_coef: 0.8895
# Epoch 38: val_loss did not improve from -0.75657
# 99/99 [==============================] - 47s 472ms/step - loss: -0.8065 - binary_accuracy: 0.9979 - iou: 0.8068 - dice_coef: 0.8895 - val_loss: -0.7532 - val_binary_accuracy: 0.9962 - val_iou: 0.7682 - val_dice_coef: 0.8553
# Epoch 39/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8080 - binary_accuracy: 0.9979 - iou: 0.8079 - dice_coef: 0.8897
# Epoch 39: val_loss improved from -0.75657 to -0.76244, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 37s 379ms/step - loss: -0.8080 - binary_accuracy: 0.9979 - iou: 0.8079 - dice_coef: 0.8897 - val_loss: -0.7624 - val_binary_accuracy: 0.9971 - val_iou: 0.7693 - val_dice_coef: 0.8564
# Epoch 40/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8127 - binary_accuracy: 0.9980 - iou: 0.8127 - dice_coef: 0.8937
# Epoch 40: val_loss did not improve from -0.76244
# 99/99 [==============================] - 36s 368ms/step - loss: -0.8127 - binary_accuracy: 0.9980 - iou: 0.8127 - dice_coef: 0.8937 - val_loss: -0.7073 - val_binary_accuracy: 0.9965 - val_iou: 0.7264 - val_dice_coef: 0.8318
# Epoch 41/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8095 - binary_accuracy: 0.9980 - iou: 0.8088 - dice_coef: 0.8911
# Epoch 41: val_loss improved from -0.76244 to -0.76453, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 37s 377ms/step - loss: -0.8095 - binary_accuracy: 0.9980 - iou: 0.8088 - dice_coef: 0.8911 - val_loss: -0.7645 - val_binary_accuracy: 0.9963 - val_iou: 0.7549 - val_dice_coef: 0.8471
# Epoch 42/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8063 - binary_accuracy: 0.9979 - iou: 0.8056 - dice_coef: 0.8896
# Epoch 42: val_loss did not improve from -0.76453
# 99/99 [==============================] - 36s 360ms/step - loss: -0.8063 - binary_accuracy: 0.9979 - iou: 0.8056 - dice_coef: 0.8896 - val_loss: -0.7462 - val_binary_accuracy: 0.9974 - val_iou: 0.7581 - val_dice_coef: 0.8497
# Epoch 43/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8110 - binary_accuracy: 0.9979 - iou: 0.8113 - dice_coef: 0.8935
# Epoch 43: val_loss improved from -0.76453 to -0.76885, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 37s 376ms/step - loss: -0.8110 - binary_accuracy: 0.9979 - iou: 0.8113 - dice_coef: 0.8935 - val_loss: -0.7689 - val_binary_accuracy: 0.9976 - val_iou: 0.7746 - val_dice_coef: 0.8678
# Epoch 44/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8034 - binary_accuracy: 0.9978 - iou: 0.8032 - dice_coef: 0.8877
# Epoch 44: val_loss did not improve from -0.76885
# 99/99 [==============================] - 36s 362ms/step - loss: -0.8034 - binary_accuracy: 0.9978 - iou: 0.8032 - dice_coef: 0.8877 - val_loss: -0.7509 - val_binary_accuracy: 0.9970 - val_iou: 0.7663 - val_dice_coef: 0.8570
# Epoch 45/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8115 - binary_accuracy: 0.9980 - iou: 0.8114 - dice_coef: 0.8933
# Epoch 45: val_loss did not improve from -0.76885
# 99/99 [==============================] - 37s 371ms/step - loss: -0.8115 - binary_accuracy: 0.9980 - iou: 0.8114 - dice_coef: 0.8933 - val_loss: -0.7620 - val_binary_accuracy: 0.9965 - val_iou: 0.7781 - val_dice_coef: 0.8583
# Epoch 46/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8134 - binary_accuracy: 0.9980 - iou: 0.8139 - dice_coef: 0.8938
# Epoch 46: val_loss did not improve from -0.76885
# 99/99 [==============================] - 37s 373ms/step - loss: -0.8134 - binary_accuracy: 0.9980 - iou: 0.8139 - dice_coef: 0.8938 - val_loss: -0.7661 - val_binary_accuracy: 0.9971 - val_iou: 0.7822 - val_dice_coef: 0.8714
# Epoch 47/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8158 - binary_accuracy: 0.9980 - iou: 0.8153 - dice_coef: 0.8949
# Epoch 47: val_loss improved from -0.76885 to -0.77284, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 38s 381ms/step - loss: -0.8158 - binary_accuracy: 0.9980 - iou: 0.8153 - dice_coef: 0.8949 - val_loss: -0.7728 - val_binary_accuracy: 0.9972 - val_iou: 0.7803 - val_dice_coef: 0.8677
# Epoch 48/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8141 - binary_accuracy: 0.9979 - iou: 0.8142 - dice_coef: 0.8952
# Epoch 48: val_loss improved from -0.77284 to -0.77899, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 360ms/step - loss: -0.8141 - binary_accuracy: 0.9979 - iou: 0.8142 - dice_coef: 0.8952 - val_loss: -0.7790 - val_binary_accuracy: 0.9973 - val_iou: 0.7943 - val_dice_coef: 0.8786
# Epoch 49/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8227 - binary_accuracy: 0.9981 - iou: 0.8231 - dice_coef: 0.9000
# Epoch 49: val_loss did not improve from -0.77899
# 99/99 [==============================] - 36s 362ms/step - loss: -0.8227 - binary_accuracy: 0.9981 - iou: 0.8231 - dice_coef: 0.9000 - val_loss: -0.7569 - val_binary_accuracy: 0.9972 - val_iou: 0.7739 - val_dice_coef: 0.8564
# Epoch 50/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8171 - binary_accuracy: 0.9980 - iou: 0.8175 - dice_coef: 0.8975
# Epoch 50: val_loss did not improve from -0.77899
# 99/99 [==============================] - 36s 368ms/step - loss: -0.8171 - binary_accuracy: 0.9980 - iou: 0.8175 - dice_coef: 0.8975 - val_loss: -0.7442 - val_binary_accuracy: 0.9970 - val_iou: 0.7620 - val_dice_coef: 0.8591
# Epoch 51/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8083 - binary_accuracy: 0.9979 - iou: 0.8083 - dice_coef: 0.8914
# Epoch 51: val_loss did not improve from -0.77899
# 99/99 [==============================] - 38s 380ms/step - loss: -0.8083 - binary_accuracy: 0.9979 - iou: 0.8083 - dice_coef: 0.8914 - val_loss: -0.7384 - val_binary_accuracy: 0.9971 - val_iou: 0.7573 - val_dice_coef: 0.8367
# Epoch 52/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8210 - binary_accuracy: 0.9980 - iou: 0.8202 - dice_coef: 0.8980
# Epoch 52: val_loss did not improve from -0.77899
# 99/99 [==============================] - 36s 365ms/step - loss: -0.8210 - binary_accuracy: 0.9980 - iou: 0.8202 - dice_coef: 0.8980 - val_loss: -0.7580 - val_binary_accuracy: 0.9971 - val_iou: 0.7521 - val_dice_coef: 0.8400
# Epoch 53/60
# 96/99 [===========================>..] - ETA: 1s - loss: -0.8261 - binary_accuracy: 0.9981 - iou: 0.8261 - dice_coef: 0.9019
# Epoch 53: val_loss improved from -0.77899 to -0.80062, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 39s 390ms/step - loss: -0.8250 - binary_accuracy: 0.9981 - iou: 0.8244 - dice_coef: 0.9009 - val_loss: -0.8006 - val_binary_accuracy: 0.9976 - val_iou: 0.8145 - val_dice_coef: 0.8937
# Epoch 54/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8165 - binary_accuracy: 0.9980 - iou: 0.8169 - dice_coef: 0.8949
# Epoch 54: val_loss did not improve from -0.80062
# 99/99 [==============================] - 37s 377ms/step - loss: -0.8165 - binary_accuracy: 0.9980 - iou: 0.8169 - dice_coef: 0.8949 - val_loss: -0.7607 - val_binary_accuracy: 0.9971 - val_iou: 0.7666 - val_dice_coef: 0.8603
# Epoch 55/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8237 - binary_accuracy: 0.9981 - iou: 0.8241 - dice_coef: 0.9014
# Epoch 55: val_loss did not improve from -0.80062
# 99/99 [==============================] - 37s 370ms/step - loss: -0.8237 - binary_accuracy: 0.9981 - iou: 0.8241 - dice_coef: 0.9014 - val_loss: -0.7887 - val_binary_accuracy: 0.9969 - val_iou: 0.8038 - val_dice_coef: 0.8842
# Epoch 56/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8300 - binary_accuracy: 0.9981 - iou: 0.8301 - dice_coef: 0.9046
# Epoch 56: val_loss did not improve from -0.80062
# 99/99 [==============================] - 36s 366ms/step - loss: -0.8300 - binary_accuracy: 0.9981 - iou: 0.8301 - dice_coef: 0.9046 - val_loss: -0.7527 - val_binary_accuracy: 0.9966 - val_iou: 0.7677 - val_dice_coef: 0.8467
# Epoch 57/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8294 - binary_accuracy: 0.9981 - iou: 0.8298 - dice_coef: 0.9042
# Epoch 57: val_loss did not improve from -0.80062
# 99/99 [==============================] - 37s 375ms/step - loss: -0.8294 - binary_accuracy: 0.9981 - iou: 0.8298 - dice_coef: 0.9042 - val_loss: -0.7715 - val_binary_accuracy: 0.9973 - val_iou: 0.7700 - val_dice_coef: 0.8560
# Epoch 58/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8259 - binary_accuracy: 0.9981 - iou: 0.8264 - dice_coef: 0.9024
# Epoch 58: val_loss did not improve from -0.80062
# 99/99 [==============================] - 35s 357ms/step - loss: -0.8259 - binary_accuracy: 0.9981 - iou: 0.8264 - dice_coef: 0.9024 - val_loss: -0.7761 - val_binary_accuracy: 0.9971 - val_iou: 0.7844 - val_dice_coef: 0.8679
# Epoch 59/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8249 - binary_accuracy: 0.9980 - iou: 0.8248 - dice_coef: 0.9008
# Epoch 59: val_loss did not improve from -0.80062
# 99/99 [==============================] - 36s 361ms/step - loss: -0.8249 - binary_accuracy: 0.9980 - iou: 0.8248 - dice_coef: 0.9008 - val_loss: -0.7687 - val_binary_accuracy: 0.9964 - val_iou: 0.7802 - val_dice_coef: 0.8645
# Epoch 60/60
# 100/99 [==============================] - ETA: 0s - loss: -0.8259 - binary_accuracy: 0.9981 - iou: 0.8258 - dice_coef: 0.9012
# Epoch 60: val_loss did not improve from -0.80062
# 99/99 [==============================] - 37s 372ms/step - loss: -0.8259 - binary_accuracy: 0.9981 - iou: 0.8258 - dice_coef: 0.9012 - val_loss: -0.7427 - val_binary_accuracy: 0.9966 - val_iou: 0.7619 - val_dice_coef: 0.8415

# %%
results = model.evaluate(data_test, steps=len(mri_df_test) / BATCH_SIZE)

print("Test loss: ",round(results[0],3),
      "Test Binary Accuracy: ",round(results[1],3),
      "Test IOU: ",round(results[2],3),
      "Test Dice Coefficent: ",round(results[3],3))
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 12/12 [==============================] - 12s 1s/step - loss: -0.8121 - binary_accuracy: 0.9979 - iou: 0.8170 - dice_coef: 0.8971
# Test loss:  -0.812 Test Binary Accuracy:  0.998 Test IOU:  0.817 Test Dice Coefficent:  0.897

# %%
for i in range(5):
    index=np.random.randint(1,len(mri_df_test.index))
    img = cv2.imread(mri_df_test['img'].iloc[index])
    img = cv2.resize(img ,(128, 128))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('True Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(mri_df_test['msk'].iloc[index])))
    plt.title('True Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
import skimage.filters
import skimage.measure


def CalculateTumorSize(mask_pred):
    thresh = skimage.filters.threshold_otsu(mask_pred)
    tumor_mask = mask_pred > thresh
    
    pixel_size = 0.1  # the size of a pixel in millimeters
    label_image = skimage.measure.label(tumor_mask)
    region_props = skimage.measure.regionprops(label_image)
    
    if len(region_props) == 0:
        tumor_size_mm = 0.0
    else:
        tumor_area = region_props[0].area
        tumor_size_mm = tumor_area * pixel_size ** 2
        
    return tumor_size_mm

# %%
for i in range(5):
    index = np.random.randint(1, len(mri_df_test.index))
    img = cv2.imread(mri_df_test['img'].iloc[index])
    img = cv2.resize(img, (128, 128))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred = model.predict(img)

    tumor_size_mm = CalculateTumorSize(np.squeeze(pred) > 0.5)
    
    plt.figure(figsize=(12, 12))
    plt.subplot(1, 3, 1)
    plt.imshow(np.squeeze(img))
    plt.title('True Image')
    
    plt.subplot(1, 3, 2)
    plt.imshow(np.squeeze(cv2.imread(mri_df_test['msk'].iloc[index])))
    plt.title('True Mask')
    
    plt.subplot(1, 3, 3)
    plt.imshow(np.squeeze(pred) > 0.5)
    plt.title(f'Tumor Size: {tumor_size_mm:.2f} mm²')
      
    plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
